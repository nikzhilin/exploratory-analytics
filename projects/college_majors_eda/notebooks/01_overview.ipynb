# %% [markdown]
# # Первичный анализ
# Базовые статистики, качество данных, одномерный, двумерный и многомерный анализ.

# %% [markdown]
# ## Загрузка библиотек

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# ## Первый взгляд

# %% [markdown]
# # ...
